# %%
import pandas as pd

data = pd.read_csv('car_stopping_distance.csv')
x = data[['Speed (mph)']]
y = data['Distance (ft)']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('poster')
from ipywidgets import interact
from sklearn.tree import DecisionTreeRegressor, plot_tree

def fitting(md):
    dt = DecisionTreeRegressor(max_depth=md)
    dt.fit(x, y)
    y_pred = dt.predict(x)

    plt.figure(figsize=(20, 13))
    plt.subplot(2, 1, 1)
    plt.scatter(x, y)
    plt.plot(x, y_pred, 'red')
    plt.xlabel('Speed (mph)')
    plt.ylabel('Distance (ft)')

    plt.subplot(2, 1, 2)
    plot_tree(dt, filled=True)

    plt.tight_layout()

interact(fitting, md=(1, 7))
# Out:
# interactive(children=(IntSlider(value=4, description='md', max=7, min=1), Output()), _dom_classes=('widget-int…
# <function __main__.fitting(md)>
